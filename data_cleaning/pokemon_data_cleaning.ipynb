# %%
import pandas as pd
from sklearn.decomposition import PCA

# %%
df = pd.read_csv('../data/pokemon.csv')
print(df.shape)
df.head()
# Out:
# (801, 41)
#                      abilities  against_bug  against_dark  against_dragon  \
# 0  ['Overgrow', 'Chlorophyll']          1.0           1.0             1.0
# 1  ['Overgrow', 'Chlorophyll']          1.0           1.0             1.0
# 2  ['Overgrow', 'Chlorophyll']          1.0           1.0             1.0
# 3     ['Blaze', 'Solar Power']          0.5           1.0             1.0
# 4     ['Blaze', 'Solar Power']          0.5           1.0             1.0
#
#    against_electric  against_fairy  against_fight  against_fire  \
# 0               0.5            0.5            0.5           2.0
# 1               0.5            0.5            0.5           2.0
# 2               0.5            0.5            0.5           2.0
# 3               1.0            0.5            1.0           0.5
# 4               1.0            0.5            1.0           0.5
#
#    against_flying  against_ghost  ...  percentage_male  pokedex_number  \
# ...

# %%
df.columns
# Out:
# Index(['abilities', 'against_bug', 'against_dark', 'against_dragon',
#        'against_electric', 'against_fairy', 'against_fight', 'against_fire',
#        'against_flying', 'against_ghost', 'against_grass', 'against_ground',
#        'against_ice', 'against_normal', 'against_poison', 'against_psychic',
#        'against_rock', 'against_steel', 'against_water', 'attack',
#        'base_egg_steps', 'base_happiness', 'base_total', 'capture_rate',
#        'classfication', 'defense', 'experience_growth', 'height_m', 'hp',
#        'japanese_name', 'name', 'percentage_male', 'pokedex_number',
#        'sp_attack', 'sp_defense', 'speed', 'type1', 'type2', 'weight_kg',
#        'generation', 'is_legendary'],
#       dtype='object')

# %%
df.type1.unique()
# Out:
# array(['grass', 'fire', 'water', 'bug', 'normal', 'poison', 'electric',
#        'ground', 'fairy', 'fighting', 'psychic', 'rock', 'ghost', 'ice',
#        'dragon', 'dark', 'steel', 'flying'], dtype=object)

# %%
cols = ['name','type1'] 
cols.extend(['against_water','against_grass','against_fire','against_electric','against_rock'])
# cols.extend([x for x in df.columns if 'against' in x])
df_small = df[cols]
print(df_small.shape)
df_small.head()
# Out:
# (801, 7)
#          name  type1  against_water  against_grass  against_fire  \
# 0   Bulbasaur  grass            0.5           0.25           2.0
# 1     Ivysaur  grass            0.5           0.25           2.0
# 2    Venusaur  grass            0.5           0.25           2.0
# 3  Charmander   fire            2.0           0.50           0.5
# 4  Charmeleon   fire            2.0           0.50           0.5
#
#    against_electric  against_rock
# 0               0.5           1.0
# 1               0.5           1.0
# 2               0.5           1.0
# 3               1.0           2.0
# 4               1.0           2.0

# %%
df_less = df_small[df_small['type1'].isin(['water','grass','fire','electric','rock'])]
print(df_less.shape)
df_less.reset_index(inplace=True,drop=True)
df_less.head()
# Out:
# (328, 7)
#          name  type1  against_water  against_grass  against_fire  \
# 0   Bulbasaur  grass            0.5           0.25           2.0
# 1     Ivysaur  grass            0.5           0.25           2.0
# 2    Venusaur  grass            0.5           0.25           2.0
# 3  Charmander   fire            2.0           0.50           0.5
# 4  Charmeleon   fire            2.0           0.50           0.5
#
#    against_electric  against_rock
# 0               0.5           1.0
# 1               0.5           1.0
# 2               0.5           1.0
# 3               1.0           2.0
# 4               1.0           2.0

# %%
df_pca = df_less.drop(['name','type1'],axis=1)
df_pca.head()
# Out:
#    against_water  against_grass  against_fire  against_electric  against_rock
# 0            0.5           0.25           2.0               0.5           1.0
# 1            0.5           0.25           2.0               0.5           1.0
# 2            0.5           0.25           2.0               0.5           1.0
# 3            2.0           0.50           0.5               1.0           2.0
# 4            2.0           0.50           0.5               1.0           2.0

# %%
df_pca.min()
# Out:
# against_water       0.25
# against_grass       0.25
# against_fire        0.25
# against_electric    0.00
# against_rock        0.50
# dtype: float64

# %%
df_pca.max()
# Out:
# against_water       4.0
# against_grass       4.0
# against_fire        4.0
# against_electric    4.0
# against_rock        4.0
# dtype: float64

# %%
pca = PCA(n_components = 2)
pca_comps = pd.DataFrame(pca.fit_transform(df_pca))
print(pca.explained_variance_ratio_)
# Out:
# [0.44451646 0.24354416]

# %%
df_less['pc1'] = pca_comps[0]
df_less['pc2'] = pca_comps[1]
df_less
# Out:
# <ipython-input-43-ecb611fa2d58>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_less['pc1'] = pca_comps[0]
# <ipython-input-43-ecb611fa2d58>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_less['pc2'] = pca_comps[1]
#            name     type1  against_water  against_grass  against_fire  \
# 0     Bulbasaur     grass            0.5           0.25           2.0
# 1       Ivysaur     grass            0.5           0.25           2.0
# ...

# %%
df_less.to_csv('../data/pokemon_small.csv',index=False)
